# %%
from transfermarkt import Player

# %%
playerId = 28003

messi = Player(playerId)
# Out:
# C:\Users\Wilson Felipe\Documents\Análise de Dados\crawling-transfermarkt\transfermarkt.py:71: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 71 of the file C:\Users\Wilson Felipe\Documents\Análise de Dados\crawling-transfermarkt\transfermarkt.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   img = BeautifulSoup(row['team']).find('img')
# ...

# %%
messi.matches
# Out:
#                competition      matchday       date venue          team  \
# 0                   LaLiga             7 2004-10-16     A  FC Barcelona
# 1                   LaLiga             8 2004-10-24     H  FC Barcelona
# 466           Copa del Rey  Second Round 2004-10-27     A  FC Barcelona
# 2                   LaLiga            14 2004-12-04     H  FC Barcelona
# 557  UEFA Champions League       Group F 2004-12-07     A  FC Barcelona
# ..                     ...           ...        ...   ...           ...
# 461                 LaLiga            16 2019-12-07     H  FC Barcelona
# 462                 LaLiga            17 2019-12-14     A  FC Barcelona
# 463                 LaLiga            10 2019-12-18     H  FC Barcelona
# 464                 LaLiga            18 2019-12-21     H  FC Barcelona
# 465                 LaLiga            19 2020-01-04     A  FC Barcelona
#
#                    opponent    result position  goals  assists yellow  \
# ...

# %%
messi.performance(by='team')
# Out:
#               appearances  goals  assists
# team
# FC Barcelona          706    618      251

# %%
messi.matches['goals'].sum() #messi total goals
# Out:
# 618

# %%
messi.matches['assists'].sum()
# Out:
# 251
